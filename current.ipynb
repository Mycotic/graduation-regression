# %%
#!pip install --upgrade pandas

# %%
# treat years as dummies
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
grad_rates = pd.read_csv("csvs/2001-2013_Graduation_Outcome_School_Level_-_ALL_ELL_SWD_ETHNICITY_GENDER_EVER_ELL_TRANSFER_SCHOOLS.csv")

# %%
grad_rates[(grad_rates["Cohort Year"]>2004)&grad_rates["Cohort Year"]<2012]
# Out:
#           DBN                     School Name      Category  Cohort Year  \
# 0      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2013
# 1      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2012
# 2      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2011
# 3      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2010
# 4      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2009
# ...       ...                             ...           ...          ...
# 20450  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2005
# 20451  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2004
# 20452  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2003
# 20453  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2002
# 20454  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2001
#
#               Cohort  Cohort #  Toal Grads #  % of cohort  Total Regents #  \
# ...

# %%
grad_rates[grad_rates['School Name'] == 'ABRAHAM LINCOLN HIGH SCHOOL'].sort_values(by='Cohort Year')
grad_rates[(grad_rates["DBN"]=="01M696")&(grad_rates["Cohort Year"]==2007)].sort_values(by="Cohort",ascending=False)
# Out:
#         DBN                     School Name      Category  Cohort Year  \
# 438  01M696  BARD HIGH SCHOOL EARLY COLLEGE  All Students         2007
# 427  01M696  BARD HIGH SCHOOL EARLY COLLEGE  All Students         2007
# 420  01M696  BARD HIGH SCHOOL EARLY COLLEGE  All Students         2007
# 408  01M696  BARD HIGH SCHOOL EARLY COLLEGE  All Students         2007
# 399  01M696  BARD HIGH SCHOOL EARLY COLLEGE  All Students         2007
#
#             Cohort  Cohort #  Toal Grads #  % of cohort  Total Regents #  \
# 438    6 year June       127           124         97.6              124
# 427    5 year June       127           124         97.6              124
# 420  5 year August       127           124         97.6              124
# 408    4 year June       125           122         97.6              122
# 399  4 year August       125           123         98.4              123
#
#      % of cohort 1  % of grads  Advanced Regents #  % of cohort 2  \
# ...

# %%
grad_rates[(grad_rates["DBN"]=="01M697")&(grad_rates["Cohort Year"]==2006)].sort_values(by="Cohort",ascending=False)
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Category, Cohort Year, Cohort, Cohort #, Toal Grads #, % of cohort, Total Regents #, % of cohort 1, % of grads, Advanced Regents #, % of cohort 2, % of grads 1, Regents without Advanced#, % of cohort 3, % of grads 2, Local #, % of cohort 4, % of grads 3, Still Enrolled #, % of cohort 5, Dropout #, % of cohort 6]
# Index: []

# %%
grad_rates[grad_rates["Cohort #"]==15]
#grad_rates = grad_rates.set_index("DBN")
grad_rates["DBN"].nunique()
# Out:
# 538

# %%
grad_rates.columns
# Out:
# Index(['DBN', 'School Name', 'Category', 'Cohort Year', 'Cohort', 'Cohort #',
#        'Toal Grads #', '% of cohort', 'Total Regents #', '% of cohort 1',
#        '% of grads', 'Advanced Regents #', '% of cohort 2', '% of grads 1',
#        'Regents without Advanced#', '% of cohort 3', '% of grads 2', 'Local #',
#        '% of cohort 4', '% of grads 3', 'Still Enrolled #', '% of cohort 5',
#        'Dropout #', '% of cohort 6'],
#       dtype='object')

# %%
demos = pd.read_csv("csvs/2006_-_2012_School_Demographics_and_Accountability_Snapshot.csv")

# %%
def trystrip(col):
    try:
        col=col.str.strip().replace("",np.nan)
    except:
        pass
    return col
demos=demos.apply(lambda x: trystrip(x))

# %%
demos["schoolyear"] = demos.schoolyear // 10000

# %%
#demos.dtypes

# %%
demos12th=demos.dropna(subset=["grade12"],axis=0)
demos12th
# Out:
#           DBN                                     Name  schoolyear fl_percent  \
# 119    01M515  LOWER EAST SIDE PREPARATORY HIGH SCHOOL        2010
# 175    01M515  LOWER EAST SIDE PREPARATORY HIGH SCHOOL        2005         77
# 176    01M515  LOWER EAST SIDE PREPARATORY HIGH SCHOOL        2006         77
# 177    01M515  LOWER EAST SIDE PREPARATORY HIGH SCHOOL        2007         77
# 178    01M515  LOWER EAST SIDE PREPARATORY HIGH SCHOOL        2008         77
# ...       ...                                      ...         ...        ...
# 7975   25Q540               QUEENS ACADEMY HIGH SCHOOL        2010
# 9128   29Q420                   SPRINGFIELD GARDENS HS        2007       27.5
# 9867   31R470                      CONCORD HIGH SCHOOL        2005       43.5
# 9869   31R470                      CONCORD HIGH SCHOOL        2007       49.7
# 10069  32K564           BUSHWICK COMMUNITY HIGH SCHOOL        2006       86.5
#
# ...

# %%
care_demos = ["ell_percent", "sped_percent", "asian_per", "black_per", "hispanic_per", "white_per", "male_per"]
#demos[demos["grade12"].notnull()]
demos.schoolyear.unique()

# %%
demo_pers = demos[["DBN", "schoolyear"]]
demos.DBN.nunique()

# %%
grad_rates[grad_rates["DBN"]=="01M696"]

# %%
grad_rates_red = grad_rates[["Cohort Year","DBN","School Name","Cohort #", "% of cohort"]]

demo_red = demos[care_demos]

# %%
grad_rates_red

# %%
demo_red

# %%
demos[demos["DBN"]=="01M015"].isnull()["grade12"]
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# Name: grade12, dtype: bool
